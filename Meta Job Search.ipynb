# %% [markdown]
# ## Problem Statement/Goal

# %% [markdown]
# ## Imports

# %%
import pandas as np
import matplotlib as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
import selenium
import requests
from bs4 import BeautifulSoup

from sklearn.model_selection import train_test_split

# %%
from craigslist import CraigslistJobs
cl_j = CraigslistJobs(site='sfbay', area='sby', category='eng',
                      filters={'is_internship': True, 'employment_type': ['full-time', 'part-time']})

for result in cl_j.get_results():
    print(result)
# Out:
# 'employment_type' is not a valid filter
# 'employment_type' is not a valid filter
# 'employment_type' is not a valid filter
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-22-9ec3931da32a> in <module>()
#       3                       filters={'is_internship': True, 'employment_type': ['full-time', 'part-time']})
#       4
# ----> 5 for result in cl_j.get_results():
#       6     print(result)
#
# ~/anaconda3/lib/python3.6/site-packages/craigslist/__init__.py in get_results(self, limit, start, sort_by, geotagged, include_details)
#     187             self.logger.info('GET %s', response.url)
#     188             self.logger.info('Response code: %s', response.status_code)
# --> 189             response.raise_for_status()  # Something failed?
#     190
#     191             soup = bs(response.content)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in raise_for_status(self)
#     933
#     934         if http_error_msg:
# --> 935             raise HTTPError(http_error_msg, response=self)
#     936
#     937     def close(self):
#
# HTTPError: 404 Client Error: Not Found for url: https://sfbay.craigslist.org/search/sby/eng?searchNearby=1&is_internship=1&s=0

# %%
res = requests.get('https://sfbay.craigslist.org/search/jjj?query=data')

# %%
BeautifulSoup(res.text, 'lxml')
# Out:
# <html><body><p>﻿<!DOCTYPE html>
#
# </p>
# <title>SF bay area jobs "data" - craigslist</title>
# <meta content='SF bay area jobs "data" - craigslist' name="description"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <link href="https://sfbay.craigslist.org/search/jjj" rel="canonical"/>
# <link href="https://sfbay.craigslist.org/search/jjj?format=rss&amp;query=data" rel="alternate" title='RSS feed for craigslist | SF bay area jobs "data" - craigslist' type="application/rss+xml"/>
# <link href="https://sfbay.craigslist.org/search/jjj?s=120&amp;query=data" rel="next"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <link href="//www.craigslist.org/styles/cl.css?v=2c141c904c21cf0b362b8a9ce62cf33c" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/search.css?v=84cf86bc094026e12fa066bbbab154ac" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/leaflet.css?v=33e3dd14c7deed955c83b6927c5e1f07" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8" media="all" rel="stylesheet" type="text/css"/>
# <link href="//www.craigslist.org/styles/tocsmaps.css?v=d3ac18e00752d21e15dc93be93a12756" media="all" rel="stylesheet" type="text/css"/>
# <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=b21742b2ebe243963373e956ea115db0">
# <![endif]-->
# <script type="text/javascript"><!--
# var areaCountry = "US";
# var areaID = "1";
# var areaRegion = "CA";
# var catAbb = "jjj";
# var countOfTotalText = "image {count} of {total}";
# var currencySymbol = "&#x0024;";
# var defaultView = "list";
# var expiredFavIDs = null;
# var imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};
# var lessInfoText = "less info";
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var maxResults = 3000;
# var noImageText = "no image";
# var pID = null;
# var postalLat = null;
# var postalLon = null;
# var purveyorCategories = null;
# var searchDistance = null;
# var sectionAbb = "jjj";
# var sectionBase = "jjj";
# var showInfoText = "show info";
# var showMapTabs = 1;
# var showingBanished = 0;
# var showingFavorites = 0;
# var starHint = "save this post in your favorites list";
# var subarea = null;
# var zoomToPosting = null;
# --></script>
# <!--[if lt IE 9]>
# <script src="//www.craigslist.org/js/html5shiv.min.js?v=c0739b14a84b052680cdee44fea07435" type="text/javascript" ></script>
#
# <script src="//www.craigslist.org/js/respond-fork.min.js?v=247e877d69233f6f77bff30aca7b5473" type="text/javascript" ></script>
#
# <![endif]-->
# <!--[if lte IE 7]>
# <script src="//www.craigslist.org/js/json2.min.js?v=6e47a4bb061d538548771024390aa00b" type="text/javascript" ></script>
#
# <![endif]-->
# <script type="text/javascript"><!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# --></script>
# <section class="page-container" id="page-top">
# <div class="bglogo"></div>
# <header class="global-header wide">
# <a class="header-logo" href="/" name="logoLink">CL</a>
# <nav class="breadcrumbs-container">
# <form action="/search/jjj" class="breadcrumbs-form" data-action="/search/###/jjj" id="breadcrumbform" method="get">
# <input name="query" type="hidden" value="data"/>
# <ul class="breadcrumbs ">
# <li class="crumb area">
# <span class="no-js">
# <a href="/">SF bay area</a>
# </span>
# <select class="js-only" id="areaAbb" name="areaAbb">
# <option value="sfbay">SF bay area</option>
# <option value="bakersfield">bakersfield</option>
# <option value="chico">chico</option>
# <option value="fresno">fresno</option>
# <option value="goldcountry">gold country</option>
# <option value="hanford">hanford</option>
# <option value="mendocino">mendocino co</option>
# <option value="merced">merced</option>
# <option value="modesto">modesto</option>
# <option value="monterey">monterey</option>
# <option value="redding">redding</option>
# <option value="reno">reno</option>
# <option value="sacramento">sacramento</option>
# <option value="slo">san luis obispo</option>
# <option value="santamaria">santa maria</option>
# <option value="stockton">stockton</option>
# <option value="susanville">susanville</option>
# <option value="visalia">visalia-tulare</option>
# <option value="yubasutter">yuba-sutter</option>
# </select>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb subarea">
# <select id="subArea" name="subArea">
# <option selected="" value="">all SF bay area</option>
# <option value="eby">east bay</option>
# <option value="nby">north bay</option>
# <option value="pen">peninsula</option>
# <option value="sfc">san francisco</option>
# <option value="scz">santa cruz</option>
# <option value="sby">south bay</option>
# </select>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb section">
# <select id="catAbb" name="catAbb">
# <option value="ccc">community</option>
# <option value="eee">events</option>
# <option value="sss">for sale</option>
# <option value="ggg">gigs</option>
# <option value="hhh">housing</option>
# <option selected="" value="jjj">jobs</option>
# <option value="rrr">resumes</option>
# <option value="bbb">services</option>
# </select>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb category">
# <select class="js-only" id="subcatAbb">
# <option value="jjj">all</option>
# <option value="ofc">admin/office</option>
# <option value="bus">business</option>
# <option value="csr">customer service</option>
# <option value="edu">education</option>
# <option value="egr">engineering</option>
# <option value="etc">etcetera</option>
# <option value="acc">finance</option>
# <option value="fbh">food/bev/hosp</option>
# <option value="lab">general labor</option>
# <option value="gov">government</option>
# <option value="hea">healthcare</option>
# <option value="hum">human resource</option>
# <option value="lgl">legal</option>
# <option value="mnu">manufacturing</option>
# <option value="mar">marketing</option>
# <option value="med">media</option>
# <option value="npo">nonprofit</option>
# <option value="rej">real estate</option>
# <option value="ret">retail/wholesale</option>
# <option value="sls">sales</option>
# <option value="spa">salon/spa/fitness</option>
# <option value="sci">science</option>
# <option value="sec">security</option>
# <option value="trd">skilled trades</option>
# <option value="sof">software</option>
# <option value="sad">systems/networking</option>
# <option value="tch">tech support</option>
# <option value="trp">transport</option>
# <option value="tfr">tv video radio</option>
# <option value="web">web design</option>
# <option value="wri">writing</option>
# </select><span class="no-js">jobs</span>
# <span class="breadcrumb-arrow">&gt;</span>
# </li>
# <li class="crumb no-js">
# <input type="submit" value="go"/>
# </li>
# </ul>
# </form>
# </nav>
# <div class="userlinks">
# <ul class="user-actions">
# <li class="user post">
# <a href="https://post.craigslist.org/c/sfo">post</a>
# </li>
# <li class="user account">
# <a href="https://accounts.craigslist.org/login/home">account</a>
# </li>
# </ul>
# <ul class="user-favs-discards">
# <li class="user">
# <div class="favorites">
# <a class="favlink" href="#"><span aria-hidden="true" class="icon icon-star fav"></span><span class="fav-number">0</span><span class="fav-label"> favorites</span></a>
# </div>
# </li>
# <li class="user discards">
# <form action="/favorites" class="unfavform js-only" method="POST">
# <div class="to-banish-page">
# <input class="lastLink" name="lastLink" type="hidden" value="//sfbay.craigslist.org/search/jjj?query=data"/>
# <input class="lastTitle" name="lastTitle" type="hidden" value='SF bay area jobs "data" - craigslist'/>
# <input class="unfaves" name="fl" type="hidden"/>
# <input name="uf" type="hidden" value="1"/>
# <a class="to-banish-page-link" href="#">
# <span aria-hidden="true" class="icon icon-trash red"></span>
# <span class="banished_count">0</span>
# <span class="discards-label"> hidden</span>
# </a>
# </div>
# </form>
# </li>
# </ul>
# </div>
# </header>
# <header class="global-header narrow">
# <a class="header-logo" href="/">CL</a>
# <nav class="breadcrumbs-container">
# <ul class="breadcrumbs">
#
#
# SF bay area            &gt;
#
# jobs
#
# </ul>
# </nav>
# <span class="linklike show-wide-header">...</span>
# </header>
# <form action="/search/jjj" class="search-form" id="searchform">
# <div class="querybox">
# <div class="form-tab js-only"><span class="search-open" title="hide search">«</span><span class="search-closed" title="show search">»</span></div>
# <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="search jobs" type="text" value="data"/>
# <button class="searchbtn" type="submit">
# <span aria-hidden="true" class="icon icon-search"></span>
# <span class="screen-reader-text">press to search craigslist</span>
# </button>
# <div class="savealert">
# <a class="saveme" data-action="save" href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Fsave%3FURL%3Dhttps%253A%252F%252Fsfbay%252Ecraigslist%252Eorg%252Fsearch%252Fjjj%253Fquery%253Ddata" title="save this search">save search</a>
# </div>
# </div>
# <div class="search-options-container">
# <h2 class="search-options-header linklike">
# <div aria-hidden="true" class="icon icon-toggle-gear"></div>
#         options<span class="options-close">close</span>
# </h2>
# <input id="excats" name="excats" type="hidden"/>
# <div class="search-options">
# <div class="searchgroup categories">
# <div class="cattitle">
# <a class="reset" href="/search/jjj" title="clear all search parameters">jobs</a>
# </div>
# <ul class="maincats">
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="lab" id="cat_lab" name="cat_id" type="checkbox" value="130"/>
# <a class="category" href="/search/lab?query=data">general labor</a> <span class="count">1543</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="trp" id="cat_trp" name="cat_id" type="checkbox" value="125"/>
# <a class="category" href="/search/trp?query=data">transportation</a> <span class="count">1165</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="etc" id="cat_etc" name="cat_id" type="checkbox" value="15"/>
# <a class="category" href="/search/etc?query=data">et cetera</a> <span class="count">694</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="fbh" id="cat_fbh" name="cat_id" type="checkbox" value="129"/>
# <a class="category" href="/search/fbh?query=data">food/beverage/hospitality</a> <span class="count">681</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="ofc" id="cat_ofc" name="cat_id" type="checkbox" value="24"/>
# <a class="category" href="/search/ofc?query=data">admin/office</a> <span class="count">355</span>
# </li>
# <li class="morecats js-only closed">
# <span class="linklike closed"><span class="plusminus">+</span>show 26 more</span>
# <span class="linklike open"><span class="plusminus">–</span>hide 26 more</span>
# <span class="count">1875</span>
# </li>
# </ul>
# <ul class="othercats closed">
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="npo" id="cat_npo" name="cat_id" type="checkbox" value="28"/>
# <a class="category" href="/search/npo?query=data">nonprofit</a> <span class="count">350</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="acc" id="cat_acc" name="cat_id" type="checkbox" value="23"/>
# <a class="category" href="/search/acc?query=data">accounting/finance</a> <span class="count">188</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="hea" id="cat_hea" name="cat_id" type="checkbox" value="26"/>
# <a class="category" href="/search/hea?query=data">healthcare</a> <span class="count">161</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="edu" id="cat_edu" name="cat_id" type="checkbox" value="57"/>
# <a class="category" href="/search/edu?query=data">education/teaching</a> <span class="count">149</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="csr" id="cat_csr" name="cat_id" type="checkbox" value="100"/>
# <a class="category" href="/search/csr?query=data">customer service</a> <span class="count">135</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="mnu" id="cat_mnu" name="cat_id" type="checkbox" value="128"/>
# <a class="category" href="/search/mnu?query=data">manufacturing</a> <span class="count">115</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="sof" id="cat_sof" name="cat_id" type="checkbox" value="21"/>
# <a class="category" href="/search/sof?query=data">software/qa/dba/etc</a> <span class="count">94</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="trd" id="cat_trd" name="cat_id" type="checkbox" value="59"/>
# <a class="category" href="/search/trd?query=data">skilled trades/artisan</a> <span class="count">93</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="sls" id="cat_sls" name="cat_id" type="checkbox" value="49"/>
# <a class="category" href="/search/sls?query=data">sales</a> <span class="count">66</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="bus" id="cat_bus" name="cat_id" type="checkbox" value="12"/>
# <a class="category" href="/search/bus?query=data">business/mgmt</a> <span class="count">58</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="hum" id="cat_hum" name="cat_id" type="checkbox" value="54"/>
# <a class="category" href="/search/hum?query=data">human resource</a> <span class="count">54</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="lgl" id="cat_lgl" name="cat_id" type="checkbox" value="47"/>
# <a class="category" href="/search/lgl?query=data">legal/paralegal</a> <span class="count">53</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="tch" id="cat_tch" name="cat_id" type="checkbox" value="55"/>
# <a class="category" href="/search/tch?query=data">technical support</a> <span class="count">50</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="ret" id="cat_ret" name="cat_id" type="checkbox" value="27"/>
# <a class="category" href="/search/ret?query=data">retail/wholesale</a> <span class="count">46</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="mar" id="cat_mar" name="cat_id" type="checkbox" value="13"/>
# <a class="category" href="/search/mar?query=data">marketing/advertising/pr</a> <span class="count">45</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="sci" id="cat_sci" name="cat_id" type="checkbox" value="75"/>
# <a class="category" href="/search/sci?query=data">science/biotech</a> <span class="count">41</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="rej" id="cat_rej" name="cat_id" type="checkbox" value="127"/>
# <a class="category" href="/search/rej?query=data">real estate</a> <span class="count">33</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="gov" id="cat_gov" name="cat_id" type="checkbox" value="61"/>
# <a class="category" href="/search/gov?query=data">government</a> <span class="count">32</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="sec" id="cat_sec" name="cat_id" type="checkbox" value="131"/>
# <a class="category" href="/search/sec?query=data">security</a> <span class="count">30</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="sad" id="cat_sad" name="cat_id" type="checkbox" value="50"/>
# <a class="category" href="/search/sad?query=data">systems/networking</a> <span class="count">25</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="egr" id="cat_egr" name="cat_id" type="checkbox" value="48"/>
# <a class="category" href="/search/egr?query=data">architect/engineer/cad</a> <span class="count">20</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="med" id="cat_med" name="cat_id" type="checkbox" value="25"/>
# <a class="category" href="/search/med?query=data">art/media/design</a> <span class="count">13</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="spa" id="cat_spa" name="cat_id" type="checkbox" value="126"/>
# <a class="category" href="/search/spa?query=data">salon/spa/fitness</a> <span class="count">8</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="wri" id="cat_wri" name="cat_id" type="checkbox" value="16"/>
# <a class="category" href="/search/wri?query=data">writing/editing</a> <span class="count">6</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="tfr" id="cat_tfr" name="cat_id" type="checkbox" value="52"/>
# <a class="category" href="/search/tfr?query=data">tv/film/video/radio</a> <span class="count">5</span>
# </li>
# <li>
# <input checked="checked" class="catcheck multi_checkbox" data-abb="web" id="cat_web" name="cat_id" type="checkbox" value="11"/>
# <a class="category" href="/search/web?query=data">web/html/info design</a> <span class="count">5</span>
# </li>
# </ul>
# <div class="selectall js-only checked"><label>
# <input checked="checked" class="catcheck selectallcb" type="checkbox"/>
# <span class="all linklike">select all</span>
# </label></div>
# </div>
# <input name="userid" type="hidden" value=""/>
# <div class="searchgroup">
# <ul>
# <li>
# <label class="srchType">
# <input class="" name="srchType" type="checkbox" value="T"/>
#            search titles only
#        </label>
# </li>
# <li>
# <label class="hasPic">
# <input class="autosubmit" name="hasPic" type="checkbox" value="1"/>
#            has image
#        </label>
# </li>
# <li>
# <label class="postedToday">
# <input class="autosubmit" name="postedToday" type="checkbox" value="1"/>
#            posted today
#        </label>
# </li>
# <li>
# <label class="bundleDuplicates">
# <input class="autosubmit" name="bundleDuplicates" type="checkbox" value="1"/>
#            bundle duplicates
#        </label>
# </li>
# <li>
# <label class="searchNearby">
# <input class="autosubmit" name="searchNearby" type="checkbox" value="1"/>
#            include nearby areas
#        </label>
# </li>
# </ul>
# <ul class="js-only nearbyAreas ">
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_17" name="nearbyArea" type="checkbox" value="63"/>
#                             bakersfield, CA <small>(bak)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_9" name="nearbyArea" type="checkbox" value="187"/>
#                             chico, CA <small>(chc)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_8" name="nearbyArea" type="checkbox" value="43"/>
#                             fresno / madera <small>(fre)</small>
# </label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_5" name="nearbyArea" type="checkbox" value="373"/>
#                             gold country <small>(gld)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_10" name="nearbyArea" type="checkbox" value="709"/>
#                             hanford-corcoran <small>(hnf)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_18" name="nearbyArea" type="checkbox" value="189"/>
#                             humboldt county <small>(hmb)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_7" name="nearbyArea" type="checkbox" value="454"/>
#                             mendocino county <small>(mdo)</small>
# </label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_4" name="nearbyArea" type="checkbox" value="285"/>
#                             merced, CA <small>(mer)</small>
# </label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_2" name="nearbyArea" type="checkbox" value="96"/>
#                             modesto, CA <small>(mod)</small>
# </label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_1" name="nearbyArea" type="checkbox" value="102"/>
#                             monterey bay <small>(mtb)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_15" name="nearbyArea" type="checkbox" value="188"/>
#                             redding, CA <small>(rdd)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_13" name="nearbyArea" type="checkbox" value="92"/>
#                             reno / tahoe <small>(rno)</small>
# </label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_3" name="nearbyArea" type="checkbox" value="12"/>
#                             sacramento <small>(sac)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_11" name="nearbyArea" type="checkbox" value="191"/>
#                             san luis obispo <small>(slo)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_19" name="nearbyArea" type="checkbox" value="62"/>
#                             santa barbara <small>(sba)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_14" name="nearbyArea" type="checkbox" value="710"/>
#                             santa maria, CA <small>(smx)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_20" name="nearbyArea" type="checkbox" value="708"/>
#                             siskiyou county <small>(ssk)</small>
# </label>
# </li>
# <li class="">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_0" name="nearbyArea" type="checkbox" value="97"/>
#                             stockton, CA <small>(stk)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_16" name="nearbyArea" type="checkbox" value="707"/>
#                             susanville, CA <small>(ssn)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_3">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_21" name="nearbyArea" type="checkbox" value="208"/>
#                             ventura county <small>(oxr)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_2">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_12" name="nearbyArea" type="checkbox" value="346"/>
#                             visalia-tulare <small>(vis)</small>
# </label>
# </li>
# <li class="nearbyZone nearbyZone_1">
# <label class="nearby">
# <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_6" name="nearbyArea" type="checkbox" value="456"/>
#                             yuba-sutter, CA <small>(ybs)</small>
# </label>
# </li>
# <li>
# <span class="nextNearbyZone linklike" data-zone="1">
#                             + show <span id="nearbyNumber">22</span> more...
#                         </span>
# </li>
# </ul>
# </div>
# <div class="searchgroup">
# <span class="searchfieldlabel">miles from zip</span>
# <input class="flatinput searchInput search_distance" inputmode="numeric" max="200" min="0" name="search_distance" placeholder="miles" size="3" type="number" value=""/>
# <input class="flatinput searchInput postal" name="postal" placeholder="from zip" size="7" type="text" value=""/>
# <span class="icon icon-locate"></span>
# </div>
# <div class="searchgroup"><label class="is_internship">
# <input class="autosubmit" name="is_internship" type="checkbox" value="1"/>
#     internship
# </label><br/>
# <label class="is_nonprofit">
# <input class="autosubmit" name="is_nonprofit" type="checkbox" value="1"/>
#     non-profit
# </label><br/>
# <label class="is_telecommuting">
# <input class="autosubmit" name="is_telecommuting" type="checkbox" value="1"/>
#     telecommute
# </label><br/>
# </div><div class="searchgroup"><div class="search-attribute " data-attr="employment_type">
# <div class="title linklike ">
# <span class="plus">▸</span><span class="minus">▾</span> employment type
#     </div>
# <ul class="list">
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="employment_type_1" name="employment_type" type="checkbox" value="1"/>
#                     full-time
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="employment_type_2" name="employment_type" type="checkbox" value="2"/>
#                     part-time
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="employment_type_3" name="employment_type" type="checkbox" value="3"/>
#                     contract
#                 </label>
# </li>
# <li class="checkbox ">
# <label>
# <input class="multi_checkbox" id="employment_type_4" name="employment_type" type="checkbox" value="4"/>
#                     employee's choice
#                 </label>
# </li>
# </ul>
# </div>
# </div>
# <div class="searchgroup resetsearch">
# <a class="reset linklike" href="/search/jjj" title="clear all search parameters">reset</a>
# <button class="searchlink linklike" type="submit">update search</button>
# </div>
# </div>
# </div>
# <div class="search-legend">
# <div class="search-view js-only">
# <div aria-expanded="false" aria-label="view options" class="dropdown dropdown-icons dropdown-arrows dropdown-view" role="toolbar">
# <ul class="dropdown-list">
# <li class="dropdown-item mode sel">
# <button data-selection="list" id="listview" title="show results in a list">
# <span class="view-list icon"></span>list
#                 </button>
# <span class="toggle-arrow"></span>
# </li>
# <li class="dropdown-item mode">
# <button data-selection="pic" id="picview" title="show results in a list with thumbnail pictures">
# <span class="view-thumb icon"></span>thumb
#                 </button>
# <span class="toggle-arrow"></span>
# </li>
# <li class="dropdown-item mode">
# <button data-selection="grid" id="gridview" title="show results side-by-side with larger pictures">
# <span class="view-gallery icon"></span>gallery
#                 </button>
# <span class="toggle-arrow"></span>
# </li>
# <li class="dropdown-item mode">
# <button data-selection="map" id="mapview" title="show results on a map">
# <span class="view-map icon"></span>map
#                     </button>
# <span class="toggle-arrow"></span>
# </li>
# </ul>
# </div>
# </div>
# <div class="search-sort">
# <div aria-expanded="false" aria-label="sort options" class="dropdown dropdown-sort dropdown-arrows" data-default-sort="rel" role="toolbar">
# <ul class="dropdown-list">
# <li aria-selected="false" class="dropdown-item mode ">
# <a data-selection="date" href="/search/jjj?sort=date&amp;query=data" title="show newest matches first">newest <span class="toggle-arrow"></span></a>
# </li>
# <li aria-selected="true" class="dropdown-item mode sel">
# <a data-selection="rel" href="/search/jjj?sort=rel&amp;query=data" title="show most relevant matches first">relevant <span class="toggle-arrow"></span></a>
# </li>
# </ul>
# </div>
# </div>
# <div class="paginator buttongroup firstpage">
# <span class="resulttotal">
# <span class="for-map">
#         displaying <span class="displaycountShow">...</span> postings
#         </span>
# </span>
# <span class="buttons">
# <a class="button first" href="/search/jjj?query=data" title="first page">&lt;&lt;</a>
# <span class="button first" title="first page">&lt;&lt;</span>
# <a class="button prev" href="/search/jjj?query=data" title="previous page">&lt; prev</a>
# <span class="button prev" title="previous page">&lt; prev</span>
# <span class="button pagenum">
# <span class="range">
# <span class="rangeFrom">1</span>
#                 -
#                 <span class="rangeTo">120</span>
# </span>
#             /
#             <span class="totalcount">3000</span>
# </span>
# <a class="button next" href="/search/jjj?s=120&amp;query=data" title="next page">next &gt; </a>
# <span class="button next" title="next page"> next &gt; </span>
# </span>
# </div>
# </div>
# <div class="content" id="sortable-results">
# <section class="favlistsection">
# <section class="favlistinfo">
# </section>
# <section class="banishlistinfo">
# </section>
# </section>
# <div class="open-map-view-button">
# <span>see in map view</span>
# </div>
# <div data-arealat="37.500000" data-arealon="-122.250000" id="mapcontainer">
# <div id="noresult-overlay"></div>
# <div id="noresult-text">
# <span class="message">No mappable items found</span>
# </div>
# <div class="loading" id="map">
# <div class="close-full-screen-map-mode-button">close fullscreen</div>
# <div class="close-map-view-button">close map</div>
# </div>
# </div>
# <ul class="rows">
# <li class="result-row" data-pid="6753159493">
# <a class="result-image gallery empty" href="https://sfbay.craigslist.org/eby/ofc/d/data-entry-order-entry/6753159493.html"></a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2018-11-19 15:08" title="Mon 19 Nov 03:08:12 PM">Nov 19</time>
# <a class="result-title hdrlnk" data-id="6753159493" href="https://sfbay.craigslist.org/eby/ofc/d/data-entry-order-entry/6753159493.html">Data Entry/Order Entry/Customer Service</a>
# <span class="result-meta">
# <span class="result-hood"> (oakland downtown)</span>
# <span class="result-tags">
# <span class="maptag" data-pid="6753159493">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="6753130324">
# <a class="result-image gallery empty" href="https://sfbay.craigslist.org/eby/ofc/d/data-entry-order-processing/6753130324.html"></a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# <li class="result-row" data-pid="6753143969">
# <a class="result-image gallery empty" href="https://sfbay.craigslist.org/pen/ofc/d/executive-assistant/6753143969.html"></a>
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2018-11-19 14:49" title="Mon 19 Nov 02:49:27 PM">Nov 19</time>
# <a class="result-title hdrlnk" data-id="6753143969" href="https://sfbay.craigslist.org/pen/ofc/d/executive-assistant/6753143969.html">Executive Assistant</a>
# <span class="result-meta">
# <span class="result-hood"> (san mateo)</span>
# <span class="result-tags">
# <span class="maptag" data-pid="6753143969">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>
# </li>
# </ul>
# </div>
# <div class="search-legend bottom">
# <div class="search-view">
# <span class="buttongroup"><a class="backtotop button" href="#page-top">^ back to top</a></span>
# </div>
# <div class="search-sort">
# <span class="buttongroup"><a class="backtotop button" href="#page-top">^ back to top</a></span>
# </div>
# <div class="paginator buttongroup firstpage">
# <span class="resulttotal">
# <span class="for-map">
#         displaying <span class="displaycountShow">...</span> postings
#         </span>
# </span>
# <span class="buttons">
# <a class="button first" href="/search/jjj?query=data" title="first page">&lt;&lt;</a>
# <span class="button first" title="first page">&lt;&lt;</span>
# <a class="button prev" href="/search/jjj?query=data" title="previous page">&lt; prev</a>
# <span class="button prev" title="previous page">&lt; prev</span>
# <span class="button pagenum">
# <span class="range">
# <span class="rangeFrom">1</span>
#                 -
#                 <span class="rangeTo">120</span>
# </span>
#             /
#             <span class="totalcount">3000</span>
# </span>
# <a class="button next" href="/search/jjj?s=120&amp;query=data" title="next page">next &gt; </a>
# <span class="button next" title="next page"> next &gt; </span>
# </span>
# </div>
# </div>
# <section class="blurbs">
# </section>
# <div id="floater">
# <img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif"/>
# <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif"/>
# </div>
# </form>
# <div class="slidemessage">
# <span class="fave">
# <span class="star"></span>
#         favorited
#     </span>
# <span class="unfave">
# <span class="star"></span>
#         no longer favorited
#     </span>
# <span class="hide">
# <span class="trash"></span>
#         hidden
#     </span>
# <span class="unhide">
# <span class="trash"></span>
#         no longer hidden
#     </span>
# </div>
# <footer>
# <span class="rss">
# <a class="l" href="https://sfbay.craigslist.org/search/jjj?format=rss&amp;query=data">RSS</a>
# <a href="https://www.craigslist.org/about/rss">(?)</a><br/>
# </span>
# <ul class="clfooter">
# <li>©  <span class="desktop">craigslist</span><span class="mobile">CL</span></li>
# <li><a href="https://www.craigslist.org/about/help/">help</a></li>
# <li><a href="https://www.craigslist.org/about/scams">safety</a></li>
# <li class="desktop"><a href="https://www.craigslist.org/about/privacy.policy">privacy</a></li>
# <li class="desktop"><a href="https://forums.craigslist.org/?forumID=8">feedback</a></li>
# <li class="desktop"><a href="https://www.craigslist.org/about/craigslist_is_hiring">cl jobs</a></li>
# <li><a href="//www.craigslist.org/about/terms.of.use.en">terms</a><sup class="neu">new</sup></li>
# <li><a href="https://www.craigslist.org/about/">about</a></li>
# <li class="fsel desktop linklike" data-mode="mobile">mobile</li>
# <li class="fsel mobile linklike" data-mode="regular">desktop</li>
# </ul>
# </footer>
# </section>
# <template id="gallerycarousel">
# <div class="slider-info"></div><div class="slider-back arrow">&lt;</div><div class="slider-forward arrow">&gt;</div>
# </template>
# <script src="//www.craigslist.org/js/general-concat.min.js?v=ec2809ab798c64f11701752083535431" type="text/javascript"></script>
# <script type="text/javascript"><!--
#         var iframe = document.createElement('iframe');
#         iframe.style.display = 'none';
#         iframe.src = '//www.' + CL.url.baseDomain + '/static/localstorage.html?v=51a29e41f8e978141e4085ed4a77d170';
#         document.body.insertBefore(iframe, null);
#     --></script>
# <script id="clustertemplate" type="text/template">
#     <li class="posting {visited}" data-pid="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#             <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#             <span class="bedrooms">{BedroomsContent}</span>
#             <span class="postingtitle"><a>{PostingTitle}</a></span>
#             <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                 <span class="banish">
#                     <span class="icon icon-trash" role="button"></span>
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#                 <span class="unbanish">
#                     <span class="icon icon-trash red" role="button"></span>
#                     unhide
#                 </span>
#             </span>
#         </div>
#     </li>
# </script>
# <script id="postingtemplate" type="text/template">
#     <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             &laquo; back to posting list
#         </div>
#         <div class="title">
#             <span class="icon icon-star" data-pid="{PostingID}" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#             <span class="postingtitle">
#                 <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                     <span class="banish">
#                         <span class="icon icon-trash" role="button"></span>
#                         <span class="screen-reader-text">hide this posting</span>
#                     </span>
#                     <span class="unbanish">
#                         <span class="icon icon-trash red" role="button"></span>
#                         <span class="screen-reader-text">unhide</span>
#                         unhide
#                     </span>
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer gallery">
#             <span class="slider-back arrow">&lt;</span><span class="slider-info"></span><span class="slider-forward arrow">&gt;</span>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <div class="timecontainer"></div>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
# </script>
# <script id="popuptemplate" type="text/template">
#     <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
# </script>
# <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=b4f9b48fd7339d4a19e71c500faae0cb" type="text/javascript"></script>
# <script src="//www.craigslist.org/js/search-concat.min.js?v=0e155aa133fc2bddf54d8aa33afebbe0" type="text/javascript"></script>
# <script src="//www.craigslist.org/js/postings-concat.min.js?v=33044b660200679fcccbf86838189c88" type="text/javascript"></script>
# </body></html>

# %%
import craigslist as cl
from craigslist import 
cl.range
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-3fa767f09d2f> in <module>()
# ----> 1 import craigslist.CraigslistJobs as cl
#
# ModuleNotFoundError: No module named 'craigslist.CraigslistJobs'

# %%
cl.CraigslistJobs()
# Out:
# Base filters:
# * query = ...
# * search_titles = True/False
# * has_image = True/False
# * posted_today = True/False
# * bundle_duplicates = True/False
# * search_distance = ...
# * zip_code = ...
# Section specific filters:
# * is_internship = True/False
# * is_nonprofit = True/False
# * is_telecommuting = True/False
# * employment_type = 'full-time', 'part-time', 'contract', "employee's choice"
# None

# %%
filters = {
    'query' : 'Data', 
    'search_titles'  : True,
    'zip_code'       : 94609,
    'employment_type': 'full-time'
}

search = cl.CraigslistJobs(#site = 'sfbay', 
                           area = 'sfc', 
                           category = 'eng',
                           filters = filters,
                           log_level = 50)

for result in search.get_results():
    print(result)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-24-038ee1e23de6> in <module>()
#      12                            log_level = 50)
#      13
# ---> 14 for result in search.get_results():
#      15     print(result)
#
# ~/anaconda3/lib/python3.6/site-packages/craigslist/__init__.py in get_results(self, limit, start, sort_by, geotagged, include_details)
#     187             self.logger.info('GET %s', response.url)
#     188             self.logger.info('Response code: %s', response.status_code)
# --> 189             response.raise_for_status()  # Something failed?
#     190
#     191             soup = bs(response.content)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in raise_for_status(self)
#     933
#     934         if http_error_msg:
# --> 935             raise HTTPError(http_error_msg, response=self)
#     936
#     937     def close(self):
#
# HTTPError: 404 Client Error: Not Found for url: https://sfbay.craigslist.org/search/sfc/eng?searchNearby=1&query=Data&srchType=T&postal=94609&s=0

# %%
cl.Craigsl

# %%
cl.CraigslistJobs.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-74950f2dc6e7> in <module>()
# ----> 1 search.fetch_content()
#
# TypeError: fetch_content() missing 1 required positional argument: 'url'

# %% [markdown]
# # Trying out new Toy: Selenium

# %% [markdown]
# Lesson: https://www.youtube.com/watch?v=F4OX5ovTkno
# Documentation: https://pypi.org/project/selenium/3

# %% [markdown]
# ## Data Collection

# %% [markdown]
# ## Initial Viewing and Cleaning

# %% [markdown]
# ## Exploritory Data Analysis

# %% [markdown]
# ## Model Prep

# %% [markdown]
# ### Model Imports & Initiations

# %% [markdown]
# ### Data Prep

# %%
#features = 
X = df[features]
y = df['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    stratify = y)

# %% [markdown]
# ## Initial Model and Results

# %% [markdown]
# ## Model Review & Improvement

# %% [markdown]
# ## Recycling Bin for Code
